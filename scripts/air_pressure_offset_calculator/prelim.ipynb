# %%
import pandas as pd

# %%
# fetch data from https://seklima.met.no/
# url: https://rim.k8s.met.no/api/v1/observations?sources=SN18700&referenceTime=2026-09-18T15:32:58Z/2026-09-19T16:32:58Z&elements=air_pressure_at_sea_level&timeResolution=hours


# data from HA
HA_data = pd.read_csv('ha.csv')

# %%
HA_data['last_changed'] = pd.to_datetime(HA_data['last_changed'])

def keep_row(row: pd.Series) -> bool:
    tim = row['last_changed']

# %%
HA_data.head()
# Out:
#                                            entity_id             state  \
# 0  sensor.kitchen_esp32_screen_sensor_station_bmp...       unavailable
# 1  sensor.kitchen_esp32_screen_sensor_station_bmp...  992.285461425781
# 2  sensor.kitchen_esp32_screen_sensor_station_bmp...  992.282104492188
# 3  sensor.kitchen_esp32_screen_sensor_station_bmp...  992.341064453125
# 4  sensor.kitchen_esp32_screen_sensor_station_bmp...  992.304626464844
#
#                       last_changed
# 0        2026-09-17 22:00:00+00:00
# 1 2026-09-18 21:11:28.483000+00:00
# 2 2026-09-18 21:12:21.669000+00:00
# 3 2026-09-18 21:13:21.660000+00:00
# 4 2026-09-18 21:14:21.674000+00:00
